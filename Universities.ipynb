# %%
import pandas as pd
import numpy as np

# %%
uni = pd.read_csv('universities.csv')

# %%
# Load the university dataset (link below) into a pandas dataframe.
# Using pandas, find both the mean and median size by each university type (as given in the dataframe), 
# ordered by average size in ascending order.
# Make new columns  in the dataframe from existing data for the following attributes:
# City
# State
# ZipCode
# Private or Public
# for-profit or not-for-profit
# primarily associate's (1 for Yes, 0 for No)
#  Using the new columns you've made above (and excluding the original type column),
# find both the mean and median size of each university by State, by Private or Public,
# and by whether the university is primarily associate's or not.
# Use the tools you've learned to compute at **least** one other aggregate from the dataset
# Save the updated dataframe as a csv  (using the pandas to_csv method) and commit your files,
# and push up to github.
# (Note: Make a new git repo on your computer and a new github repo in the cloud for this assignment.
# Save, commit and push often!!!

# %%
uni.head(20)
# Out:
#                                                  name  \
# 0             A T Still University of Health Sciences
# 1                        Abilene Christian University
# 2                Abraham Baldwin Agricultural College
# 3                                     Academy College
# 4                Academy for Five Element Acupuncture
# 5                           Academy of Art University
# 6      Academy of Chinese Culture and Health Sciences
# 7                        Academy of Oriental Medicine
# 8                               Academy of Vocal Arts
# 9   Acupuncture and Integrative Medicine College-B...
# 10                    Acupuncture and Massage College
# 11                                Adams State College
# 12                                 Adelphi University
# 13                              Adler Graduate School
# 14            Adler School of Professional Psychology
# 15                                     Adrian College
# ...

# %%
uni.columns
# Out:
# Index(['name', 'address', 'Website', 'Type', 'Size'], dtype='object')

# %%
uni.describe
# Out:
# <bound method NDFrame.describe of                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# ...

# %%
conv = pd.to_numeric(uni['Size'], 'coerce')
conv
# Out:
# 0        3480.0
# 1        4669.0
# 2        3600.0
# 3         165.0
# 4          51.0
#          ...
# 2902      139.0
# 2903      396.0
# 2904     5627.0
# 2905    13704.0
# 2906      247.0
# Name: Size, Length: 2907, dtype: float64

# %%
uni.describe()
# Out:
#                Size
# count    2829.00000
# mean     4374.88123
# std      9256.38326
# min         4.00000
# 25%       493.00000
# 50%      1478.00000
# 75%      4064.00000
# max    301323.00000

# %%
uni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2907 non-null   object
#  1   address  2907 non-null   object
#  2   Website  2822 non-null   object
#  3   Type     2907 non-null   object
#  4   Size     2829 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 113.7+ KB

# %%
uni[conv.isna()]
# Out:
#                                         name  \
# 38          Alliant International University
# 39          Alliant International University
# 40          Alliant International University
# 42          Alliant International University
# 43          Alliant International University
# ...                                      ...
# 2753     Washington State University-Spokane
# 2754  Washington State University-Tri Cities
# 2755   Washington State University-Vancouver
# 2801             Western Seminary-Sacramento
# 2802               Western Seminary-San Jose
#
#                                                 address  \
# 38    One Beach Street, Suite 100, San Francisco, Ca...
# 39    2500 Michelson Dr-Ste 250, Irvine, California ...
# 40    2595 Capital Oaks Drive, Suite 200, Sacramento...
# 42    5130 E Clinton Way, Fresno, California 93727-1360
# 43    1000 S Fremont Ave, Unit 5, Alhambra, Californ...
# ...                                                 ...
# ...

# %%
uni.columns
# Out:
# Index(['name', 'address', 'Website', 'Type', 'Size'], dtype='object')

# %%
uni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2907 non-null   object
#  1   address  2907 non-null   object
#  2   Website  2822 non-null   object
#  3   Type     2907 non-null   object
#  4   Size     2829 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 113.7+ KB

# %%
uni.describe()
# Out:
#                Size
# count    2829.00000
# mean     4374.88123
# std      9256.38326
# min         4.00000
# 25%       493.00000
# 50%      1478.00000
# 75%      4064.00000
# max    301323.00000

# %%
uni = uni[uni.Size.notna()]
uni
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
uni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2829 entries, 0 to 2906
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2829 non-null   object
#  1   address  2829 non-null   object
#  2   Website  2746 non-null   object
#  3   Type     2829 non-null   object
#  4   Size     2829 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 132.6+ KB

# %%
uni['Type'].value_counts()
# Out:
# 4-year, Private not-for-profit                           1579
# 4-year, Public                                            618
# 4-year, Private for-profit                                284
# 4-year, primarily associate's, Private for-profit         268
# 4-year, primarily associate's, Private not-for-profit      87
# 4-year, primarily associate's, Public                      71
# Name: Type, dtype: int64

# %%
addy = uni['address']

# %%
address = addy.str.rsplit(',',2,expand=True)
address
# Out:
#                                    0             1                         2
# 0                    800 W Jefferson    Kirksville            Missouri 63501
# 1                  1600 Campus Court       Abilene               Texas 79699
# 2                     2802 Moore Hwy        Tifton        Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100   Minneapolis      Minnesota 55420-1554
# 4                     305 SE 2nd Ave   Gainesville             Florida 32601
# ...                              ...           ...                       ...
# 2902   13315 W. Washington Boulevard   Los Angeles          California 90066
# 2903                   1125 E 8th St          York       Nebraska 68467-2699
# 2904                 Country Club Rd          York   Pennsylvania 17403-3651
# 2905            One University Plaza    Youngstown           Ohio 44555-0001
# 2906           320 South Main Street     Haverhill       Massachusetts 01835
#
# [2829 rows x 3 columns]

# %%
#city is index 1
uni['City'] = address.iloc[:,1]
uni['City']
# Out:
# 0         Kirksville
# 1            Abilene
# 2             Tifton
# 3        Minneapolis
# 4        Gainesville
#             ...
# 2902     Los Angeles
# 2903            York
# 2904            York
# 2905      Youngstown
# 2906       Haverhill
# Name: City, Length: 2829, dtype: object

# %%
#State
uni['State'] = address.iloc[:, 2]
state = uni['State']
statey = state.str.rsplit(" ", n=1, expand=True)
uni['State'] = statey.iloc[:,0]
# staten = statey.str.rsplit(" ", n=1)
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
uni['ZipCode'] = statey.iloc[:,1]
uni
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
# pop = uni['Public_Or_Private']
# for num in pop:
#     if num < 0:
#         return 
pop = pop.replace(8, 1)
pop = pop.replace(31, 1)
pop = pop.replace(-1, 0)
uni['Public_Or_Private'] = pop
uni
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
typo = uni['Type']
typed = typo.str.rsplit(" ", n=1, expand=True)
uni['For-Profit or Not-For-Profit'] = typed.iloc[:, 1]
uni['For-Profit or Not-For-Profit'] = uni['For-Profit or Not-For-Profit'].replace('Public', 'not-for-profit')
uni
# for-profit or not-for-profit
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
# sub = 'Private'
# uni['Public_Or_Private'] = uni['Type'].str.find(sub)
# uni['Public_Or_Private']
# Out:
# 0        8
# 1        8
# 2       -1
# 3       31
# 4        8
#         ..
# 2902     8
# 2903     8
# 2904     8
# 2905    -1
# 2906     8
# Name: Public_Or_Private, Length: 2829, dtype: int64

# %%
# uni['Private_or_Public'] = 
# uni['Type'] = type.find('Private')
# uni['Public_or_Private'] = uni[uni['Type'].str.find('Private')]

# sub = 'Private'
# uni['Public_Or_Private'] = uni['Type'].str.find(sub)
# uni['Public_Or_Private']
# uni.columns

# %%
# for i in uni['Public_Or_Private']:
#     if i == -1:
#         i == 0
#     else: i == 1

# %%
# # pub_uni = uni[uni['Type'].str.match('4-year, Public')]
# # pruni_nfp = uni[uni['Type'].str.match('4-year, Private not-for-profit')]
# # pruni_fp = uni[uni['Type'].str.match('4-year, Private for-profit')]
# a =pd.DataFrame({'Fruit_price': fruit_prices, 'Inv': inventory})

# %%
# address = address.str.rsplit(',',2,expand=True)
